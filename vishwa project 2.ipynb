# %%
#WELCOME MESSAGE
print("======WELCOME MESSAGE======")
print("Welcome to the pattern generator and number analyzer program!")
print("You can also coontrol the flow of the program using control statements.")
print("You can also enter a number of rows for the control statement section to see how it works.\n")
print("Let's get started!\n")

#PATTERN GENERATOR
print("===Pattern Generator===")
rows = int(input("Enter number of rows:"))
print("\nTriangle Pattern")
for i in range(1, rows + 1):
    for j in range(i):
        print("*", end=" ")
    print()

#NUMBER ANALYSIS
print("\n===Number Analyzer===")
start = int(input("Enter start number: "))
end = int(input("Enter end number:"))
 
total = 0

for num in range(start, end + 1):
    if num % 2 == 0:
        print(num, "is Even")
        total = total + num
    else:
        print(num, "is Odd")

print("Sum of all numbers=", total)


#CONTROL STATEMENT
print("===Control statements===")
rows = int(input("Enter number of rows: "))
if rows <= 0:
    print("Invalid row count!")
else:
    for i in range(1, rows+1):
        if i == 5:
            pass  #placeholder for future logic
        if i > 10:
            break #stop pattern generation
        print("*" *i)

while True:
    print("\nMenu")
    print("1. Generate Triangle Pattern")
    print("2. numbers Analyze")
    print("3. Exit")
     
    choice = input("Enter your choice (1-3):")

    #PATTERN GENRATER
    if choice == "1":
       print("\npattern  type: right-angled triangle")
       print("1.Right-angled triangle")
       rows = int(input("Enter number of rows:"))
       if rows <= 0:
           print("Invalid row count! Please enter a positive number.")
           break
       
       if  rows == "triangle":
            print("\nGenrated Pattern:")
            for i in range(1,rows + 1):
                for j in range(i):
                   print("*", end=" ")
                print()
    else:
        print("Pattern type not avalilable")
        break
    if rows == "triangle":
        print("\nGenerated Pattern:")
        for i in range(1, rows + 1):
            for j in range(i):
                print("*", end=" ")
                print()
        else:
          print("Pattern type not available:")
    elif choice == "2":
        print("\nNumber Analysis")

        start = int(input("Enter start range: "))
        end = int(input("Enter end range: "))
        if end < start:
            print("Error! End range must be greater than or equal to atart range:")

        print("\nEven Numbers:")
        for  num in range(start, end + 1):
            if num % 2 == 0:
                print(num, end=" ")

        print("\nOddmNumbers:")
        for num in range(start, end + 1):
            if num % 2 != 0:
                print(num, end=" ")

        total = 0
        for num in range(start, end + 1):
            total =  total + num
        
        print("\n\nSum of all numbers in the range =", total)
    elif choice == "3":
        print("\nThank yoy for using the student data organizer!")
        print("program exicuted successfully.")
        break
    else:
        print("Invalid choice! please select a valid option.")

#THANK YOU MESSAGE
print("======THANK YOU MESSAGE======")
print("\nThank yoy for using the student data organizer!")
print("program exicuted successfully.")
# Out:
# ======WELCOME MESSAGE======
# Welcome to the pattern generator and number analyzer program!
# You can also coontrol the flow of the program using control statements.
# You can also enter a number of rows for the control statement section to see how it works.
#
# Let's get started!
#
# ===Pattern Generator===
#
# Triangle Pattern
# *
#
# ===Number Analyzer===
# 1 is Odd
# 2 is Even
# 3 is Odd
# 4 is Even
# 5 is Odd
# 6 is Even
# 7 is Odd
# 8 is Even
# 9 is Odd
# 10 is Even
# 11 is Odd
# 12 is Even
# 13 is Odd
# 14 is Even
# 15 is Odd
# 16 is Even
# 17 is Odd
# 18 is Even
# 19 is Odd
# 20 is Even
# Sum of all numbers= 110
# ===Control statements===
# *
# **
#
# Menu
# 1. Generate Triangle Pattern
# 2. numbers Analyze
# 3. Exit
# Pattern type not avalilable
# ======THANK YOU MESSAGE======
#
# Thank yoy for using the student data organizer!
# program exicuted successfully.
